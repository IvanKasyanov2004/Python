# %% [markdown]
# # Pandas (продолжение)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Упражнение 1
#
# Найдите и выведи индексы пропущенных значений.
# Заполните пропущеные значения следующими способами:
#
# 1) Среднимим значения
# 2) Медианными значениями
# 3) Наиболее часто встечающимися
# 4) Линейной интерполяцией

# %%
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5003, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

# %%
df
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %%
mask = pd.isnull(df["ord_no"])
df[mask]["ord_no"] = df["ord_no"].mean()
df["ord_no"].fillna(df["ord_no"].mean(), inplace=True)

df
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_24512/2294112427.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[mask]["ord_no"] = df["ord_no"].mean()
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.00     150.50     10.50  2012-10-05         3002       5002.0
# 1   70006.25        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.00      65.26       NaN         NaN         3001       5001.0
# 3   70004.00     110.50     11.50  2012-08-17         3003          NaN
# 4   70006.25     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.00        NaN       NaN  2012-07-27         3001       5001.0
# ...

# %%
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5003, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

df
df[pd.isna(df["ord_no"]) == True]
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0
# 6      NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 10     NaN      75.29     75.29  2012-08-17         3001       5003.0

# %%
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5003, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

print(df[pd.isna(df["ord_no"]) == True].index)
print(df[pd.isna(df["purch_amt"]) == True].index)
print(df[pd.isna(df["ord_date"]) == True].index)
print(df[pd.isna(df["customer_id"]) == True].index)
print(df[pd.isna(df["salesman_id"]) == True].index)
# Out:
# Int64Index([1, 4, 6, 10], dtype='int64')
# Int64Index([1, 5, 8], dtype='int64')
# Int64Index([2], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([3, 7, 11], dtype='int64')
# <class 'str'>

# %%
import numpy as np
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5003, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

mask = pd.isna(df["ord_no"])
df[mask]["ord_no"] = df["ord_no"].mean()
df["ord_no"].fillna(df["ord_no"].mean(), inplace=True)

mask = pd.isna(df["purch_amt"])
df["purch_amt"].fillna(df["purch_amt"].mean(), inplace = True)

df["sale_amt"].fillna(df["sale_amt"].mean(), inplace = True)

df["salesman_id"].fillna(df["salesman_id"].mean(), inplace = True)

a = np.array([])
for i in range(12):
    if i != 2:
        d = df["ord_date"][i].split("-")
        v = 30 * int(d[1]) + int(d[2])
        a = np.append(a, v)
mon = int(a.mean() // 30)
day = round(a.mean() % 30)
date = '2012-' + str(mon) + '-' + str(day)
df["ord_date"][2] = date

df
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_24512/59329045.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[mask]["ord_no"] = df["ord_no"].mean()
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_24512/59329045.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ord_date"][2] = date
#       ord_no    purch_amt   sale_amt    ord_date  customer_id  salesman_id
# 0   70001.00   150.500000  10.500000  2012-10-05         3002       5002.0
# 1   70006.25  1376.614444  20.650000  2012-09-10         3001       5003.0
# ...

# %%
import numpy as np
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5003, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

mask = pd.isna(df["ord_no"])
df[mask]["ord_no"] = df["ord_no"].median()
df["ord_no"].fillna(df["ord_no"].median(), inplace=True)

df["purch_amt"].fillna(df["purch_amt"].median(), inplace = True)

df["sale_amt"].fillna(df["sale_amt"].median(), inplace = True)

df["salesman_id"].fillna(df["salesman_id"].median(), inplace = True)

a = np.array([])
for i in range(12):
    if i != 2:
        d = df["ord_date"][i].split("-")
        v = 30 * int(d[1]) + int(d[2])
        a = np.append(a, v)
mon = int(np.median(a) // 30)
day = round(np.median(a) % 30)
date = '2012-' + str(mon) + '-' + str(day)
df["ord_date"][2] = date

df
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_24512/2579879691.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[mask]["ord_no"] = df["ord_no"].median()
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_24512/2579879691.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ord_date"][2] = date
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70004.5     250.45     20.65  2012-09-10         3001       5003.0
# ...

# %%
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5002, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

df.groupby("ord_no").agg({"ord_no": "count"})

e = df.groupby("salesman_id").agg({"salesman_id": "count"}) 
e.sort_values(by="salesman_id", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/ivankasyanov/Downloads/lpr2022_lab7.ipynb Ячейка 11 in <cell line: 12>()
#       <a href='vscode-notebook-cell:/Users/ivankasyanov/Downloads/lpr2022_lab7.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> df.groupby("ord_no").agg({"ord_no": "count"})
#      <a href='vscode-notebook-cell:/Users/ivankasyanov/Downloads/lpr2022_lab7.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a> e = df.groupby("salesman_id").agg({"salesman_id": "count"})
# ---> <a href='vscode-notebook-cell:/Users/ivankasyanov/Downloads/lpr2022_lab7.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a> e.sort_values(by="salesman_id", ascending = False)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
# ...

# %%
df = pd.DataFrame({
'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
'purch_amt': [150.5, np.nan, 65.26, 110.5, 948.5, np.nan, 5760, 1983.43, np.nan, 250.45, 75.29, 3045.6],
'sale_amt': [10.5, 20.65, np.nan, 11.5, 98.5, np.nan, 57, 19.43, np.nan, 25.45, 75.29, 35.6],
'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
'salesman_id': [5002, 5002, 5001,np.nan, 5002, 5001, 5001,np.nan, 5003, 5002, 5003,np.nan]})

df.interpolate()
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50    10.500  2012-10-05         3002       5002.0
# 1   70001.5     107.88    20.650  2012-09-10         3001       5002.0
# 2   70002.0      65.26    16.075         NaN         3001       5001.0
# 3   70004.0     110.50    11.500  2012-08-17         3003       5001.5
# 4   70004.5     948.50    98.500  2012-09-10         3002       5002.0
# 5   70005.0    3354.25    77.750  2012-07-27         3001       5001.0
# 6   70007.5    5760.00    57.000  2012-09-10         3001       5001.0
# 7   70010.0    1983.43    19.430  2012-10-10         3004       5002.0
# 8   70003.0    1116.94    22.440  2012-10-10         3003       5003.0
# 9   70012.0     250.45    25.450  2012-06-27         3002       5002.0
# 10  70012.5      75.29    75.290  2012-08-17         3001       5003.0
# 11  70013.0    3045.60    35.600  2012-04-25         3001       5003.0

# %% [markdown]
# ## Упражнение 2
#
#
# DataFrame дан ниже
#
#
# 1. Найдите все алмазы которые по любому линейному размеру больше 5.
#
# 2. Создайте новый DataFrame в которому исключены все не чсиловые столбы исходного DataFrame.
#
# 3. Расчитатйте средние значения для каждого столбца
#
# 4. Пострйоет график средних цен для каждой категории (cut) алмазов.
#
# 5. Постройте гистрограмму  веса ('carat') алмазов.
#
# 6. Посчитаете все пропущенные занчения в Dataframe
#
# 7. Создайте новый DataFrame в которому исключены все строки с пропущенными занчениями
#
# 8. Узнайте реальное использование оперативной памяти вашим DataFrame
#
# 9. Напишите функцию возращающую 20 случайныз строчек из DataFrame (без повторений)

# %%
import pandas as pd
diamonds = pd.read_csv("diamonds.csv")

diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
import pandas as pd
diamonds = pd.read_csv("diamonds.csv")

diamonds[(diamonds["x"] > 5) & (diamonds["y"] > 5) & (diamonds["z"] > 5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# ...

# %%
import pandas as pd
diamonds = pd.read_csv("diamonds.csv")
dn = diamonds.loc[:, ["carat", "depth", "table", "price", "x", "y", "z"]]
dn
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
dn.mean()
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
dcut = diamonds.groupby("cut").agg({"price": "mean"})
import matplotlib.pyplot as plt
dcut.plot(kind = "bar")
# Out:
# <AxesSubplot: xlabel='cut'>

# %%
import numpy as np
dcarat = diamonds["carat"]
type(dcarat)
a = np.array([])
a = dcarat
import matplotlib.pyplot as plt
plt.hist(a, bins=200)
plt.show()

# %%
diamonds[(pd.isna(diamonds["carat"]) == True) | (pd.isna(diamonds["depth"]) ==  True) | (pd.isna(diamonds["table"]) ==  True) | (pd.isna(diamonds["price"]) ==  True) | (pd.isna(diamonds["x"]) ==  True) | (pd.isna(diamonds["y"]) ==  True) | (pd.isna(diamonds["z"]) ==  True)].count()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamonds1 = diamonds[(pd.isna(diamonds["carat"]) == False) | (pd.isna(diamonds["depth"]) ==  False) | (pd.isna(diamonds["table"]) ==  False) | (pd.isna(diamonds["price"]) ==  False) | (pd.isna(diamonds["x"]) ==  False) | (pd.isna(diamonds["y"]) ==  False) | (pd.isna(diamonds["z"]) ==  False)]
diamonds1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 12.2 MB

# %%
def random_numbers():
    n = np.sort(random.sample(range(len(diamonds)), 20))
    return diamonds.iloc[n]

random_numbers()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 684     0.66      Ideal     D     VS1   62.1   56.0   2851  5.54  5.57  3.45
# 5013    1.10      Ideal     F      I1   61.8   56.0   3745  6.65  6.61  4.10
# 9370    0.32  Very Good     D     SI1   62.8   56.0    589  4.34  4.35  2.73
# 10127   1.11      Ideal     H     SI2   62.6   56.0   4719  6.58  6.65  4.14
# 16905   1.18      Ideal     I    VVS1   62.6   54.0   6750  6.74  6.78  4.23
# 19734   1.54  Very Good     H     SI2   62.3   56.0   8301  7.33  7.38  4.58
# 23136   2.01       Fair     E     SI2   65.5   56.0  11156  7.84  7.79  5.12
# 24929   1.50      Ideal     G     VS1   61.8   56.0  13377  7.38  7.31  4.54
# 27469   2.04  Very Good     I     VS1   61.8   60.0  18127  8.11  8.21  5.04
# 27751   0.32    Premium     I     VS1   62.6   58.0    648  4.40  4.38  2.75
# 28469   0.32      Ideal     H     VS1   62.1   55.0    672  4.40  4.39  2.73
# ...

# %% [markdown]
# ## Упражнение 3
# ##### ~определенно не баян~ classic
#
# Наконец-то, пришло время взяться за настоящий дата инжениринг и дата саенс. Датасет [титаник](https://www.kaggle.com/c/titanic).
#
# 1. Найдите два отдельных распределения по классам и возрастам пассажиров Титаника.
# 2. Разделите на две возрастные группы такие, что в них входят одинаковое количество пассажиров определенного класса. Определить такие группы для каждого пола (male/female)
# 3. На основе полученных групп определите доли выживших. (должно получится 12 чисел)
# 4. Найдите средний возраст выжившего для каждого из полов на основе полного набора данных
# 5. Найдите несмещенное среднеквадратическое отклонение возраста для выживших
# 6. Постройте график зависимости доли выживаемости от возроста
# 7. Постройте куммулятивный график выживаемости в зависимости от возраста для разных полов
# 8. Определите общие расходы пассажиров
# 9. Средих всех пассажиров найдите Екатерин (`Kate`, `Katerina`, `Ekaterina` ...)
# 10. `*`Определите имена для мужчин и женщин, которые чаще остальных встречались на корабле. Выведите список первых пяти.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

titanic = pd.read_csv("titanic.csv")

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
classes = titanic.groupby(['pclass']).agg({"pclass": "count"})
classes
ages = titanic.groupby(['age']).agg({"age": "count"})
ages
# Out:
#        age
# age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
# ...    ...
# 70.00    2
# 70.50    1
# 71.00    2
# 74.00    1
# 80.00    1
#
# [88 rows x 1 columns]

# %%
tit = tit[pd.isna(tit['age']) == False]

first_male = tit[(tit['sex'] == "male") & (tit['pclass'] == 1)].sort_values(by="age", ascending = True)
first_male_younger = first_male.iloc[:int(len(first_male)/2)]
first_male_older = first_male.iloc[int(len(first_male)/2):]

first_female = tit[(tit['sex'] == "female") & (tit['pclass'] == 1)].sort_values(by="age", ascending = True)
first_female_younger = first_female.iloc[:int(len(first_female)/2)]
first_female_older = first_female.iloc[int(len(first_female)/2):]

second_male = tit[(tit['sex'] == "male") & (tit['pclass'] == 2)].sort_values(by="age", ascending = True)
second_male_younger = second_male.iloc[:int(len(second_male)/2)]
second_male_older = second_male.iloc[int(len(second_male)/2):]

second_female = tit[(tit['sex'] == "female") & (tit['pclass'] == 2)].sort_values(by="age", ascending = True)
second_female_younger = second_female.iloc[:int(len(second_female)/2)]
second_female_older = second_female.iloc[int(len(second_female)/2):] 

third_male = tit[(tit['sex'] == "male") & (tit['pclass'] == 3)].sort_values(by="age", ascending = True)
third_male_younger = third_male.iloc[:int(len(third_male)/2)]
third_male_older = third_male.iloc[int(len(third_male)/2):]

third_female = tit[(tit['sex'] == "female") & (tit['pclass'] == 3)].sort_values(by="age", ascending = True)
third_female_younger = third_female.iloc[:int(len(third_female)/2)]
third_female_older = third_female.iloc[int(len(third_female)/2):]

# %%
k = pd.DataFrame({"male younger": [first_male_younger['survived'].mean(), second_male_younger['survived'].mean() , third_male_younger['survived'].mean()],
"male older": [first_male_older['survived'].mean(), second_male_older['survived'].mean() , third_male_older['survived'].mean()],
"female younger": [first_female_younger['survived'].mean(), second_female_younger['survived'].mean() , third_female_younger['survived'].mean()],
"female older": [first_female_older['survived'].mean(), second_female_older['survived'].mean() , third_female_older['survived'].mean()]}, index = ["1", "2", "3"])
k
# Out:
#    male younger  male older  female younger  female older
# 1      0.500000    0.294118        0.952381      0.976744
# 2      0.204082    0.100000        0.918919      0.918919
# 3      0.150794    0.149606        0.490196      0.431373

# %%
print(titanic[(titanic['sex'] == "male") & (titanic['survived'] == 1)]['age'].mean())
print(titanic[(tit['sex'] == "female") & (titanic['survived'] == 1)]['age'].mean())
# Out:
# 27.276021505376345
# 28.84771573604061

# %%
titanic[titanic['survived'] == 1]['age'].std()
# Out:
# 14.950951984140428

# %%
titage = tit.sort_values(by="age", ascending = True)
agemax = titage.iloc[len(tit) - 1, 3]
a = len(tit)/20
y = np.array([])
for i in range(20):
    y = np.append(y, titage.iloc[int(a * i): int(a * (i + 1))]['survived'].mean())
y
x = np.linspace(0, agemax, 20)

plt.plot(x,y)
plt.xlabel("age")
plt.ylabel("survived")

plt.show()

# %%
agemale = titage[titage['sex'] == "male"]

agefemale = titage[titage['sex'] == "female"]

agemaxmale = agemale.iloc[len(agemale) - 1, 3]
a1 = len(agemale)/20
y1 = np.array([])
for i in range(20):
    y1 = np.append(y1, agemale.iloc[0: int(a * i)]['survived'].mean())
y1
x1 = np.linspace(0, agemaxmale, 20)

plt.plot(x1,y1)
plt.title("male survive")
plt.xlabel("age")
plt.ylabel("survived")

plt.show()

# %%
agefemale = titage[titage['sex'] == "male"]

agefemale = titage[titage['sex'] == "female"]

agemaxfemale = agefemale.iloc[len(agefemale) - 1, 3]
a2 = len(agefemale)/20
y2 = np.array([])
for i in range(20):
    y2 = np.append(y2, agefemale.iloc[0: int(a * (i + 1))]['survived'].mean())
y2
x2 = np.linspace(0, agemaxfemale, 20)

plt.plot(x2,y2)
plt.title("female survive")
plt.xlabel("age")
plt.ylabel("survived")

plt.show()

# %%
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 803         1       3    male   0.42      0      1   8.5167        C   Third
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 644         1       3  female   0.75      2      1  19.2583        C   Third
# 469         1       3  female   0.75      2      1  19.2583        C   Third
# 78          1       2    male   0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 116         0       3    male  70.50      0      0   7.7500        Q   Third
# 493         0       1    male  71.00      0      0  49.5042        C   First
# 96          0       1    male  71.00      0      0  34.6542        C   First
# 851         0       3    male  74.00      0      0   7.7750        S   Third
# 630         1       1    male  80.00      0      0  30.0000        S   First
#
# ...

# %%
titanic['fare'].sum()
# Out:
# 28693.9493
